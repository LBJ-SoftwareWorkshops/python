# %%
### Setup chunk

import pandas as pd
import numpy as np

salaries = pd.read_csv("ds_salaries.csv")
salaries
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
# loc uses row and column labels

salaries.loc[:9, ["work_year", "experience_level"]]
# Out:
#    work_year experience_level
# 0       2020               MI
# 1       2020               SE
# 2       2020               SE
# 3       2020               MI
# 4       2020               SE
# 5       2020               EN
# 6       2020               SE
# 7       2020               MI
# 8       2020               MI
# 9       2020               SE

# %%
# iloc uses row and column indexes

salaries.iloc[:9, [1,2]]
# Out:
#    work_year experience_level
# 0       2020               MI
# 1       2020               SE
# 2       2020               SE
# 3       2020               MI
# 4       2020               SE
# 5       2020               EN
# 6       2020               SE
# 7       2020               MI
# 8       2020               MI

# %%
demo = pd.DataFrame(
    np.random.randint(100, size=(4,4)),
    columns = ["age", "sales", "discounts", "satisfaction score"]
)
demo

#demo.loc[["heather", "estefania"], ["sales", "discounts"]]
# Out:
#   Cell In [42], line 5
#     old = demo[demo.satisfaction score > 64]
#                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
selected_columns = ["work_year", "job_title", "employment_type", "salary"]
salaries[selected_columns]

# ^ this, is the same as this:

salaries[["work_year", "job_title", "employment_type", "salary"]]
# Out:
#      work_year                   job_title employment_type  salary
# 0         2020              Data Scientist              FT   70000
# 1         2020  Machine Learning Scientist              FT  260000
# 2         2020           Big Data Engineer              FT   85000
# 3         2020        Product Data Analyst              FT   20000
# 4         2020   Machine Learning Engineer              FT  150000
# ..         ...                         ...             ...     ...
# 602       2022               Data Engineer              FT  154000
# 603       2022               Data Engineer              FT  126000
# 604       2022                Data Analyst              FT  129000
# 605       2022                Data Analyst              FT  150000
# 606       2022                AI Scientist              FT  200000
#
# [607 rows x 4 columns]

# %%
full_time = salaries[salaries.employment_type == "FT"]
full_time2 = salaries[salaries["employment_type"] == "FT"]
full_time.head()

### The first method can only be used, when the variable name doesn't have a space
### Spaces in methods confuse python (pandas)
# Out:
#     Unnamed: 0  work_year experience_level employment_type  \
# 28          28       2020               EN              CT
# 45          45       2020               EN              PT
# 54          54       2020               SE              FL
# 62          62       2020               EN              PT
# 77          77       2021               MI              PT
#
#                         job_title  salary salary_currency  salary_in_usd  \
# 28          Business Data Analyst  100000             USD         100000
# 45                    ML Engineer   14000             EUR          15966
# 54       Computer Vision Engineer   60000             USD          60000
# 62                 Data Scientist   19000             EUR          21669
# 77  3D Computer Vision Researcher  400000             INR           5409
#
#    employee_residence  remote_ratio company_location company_size
# 28                 US           100               US            L
# ...

# %%
### Filtering by multiple conditions:

full_time2020 = salaries[(salaries["work_year"] == 2020) | (salaries["work_year"] == 2021)]

### ^ is the same as

years2020_2021 = salaries[salaries["work_year"].isin([2020, 2021])]

#years2020_2021

### When you want to filter by NOT meeting the condition:

not2020_2021 = salaries[~salaries["work_year"].isin([2020, 2021])]
not2020_2021
# Out:
#      Unnamed: 0  work_year experience_level employment_type       job_title  \
# 289         289       2022               SE              FT   Data Engineer
# 290         290       2022               SE              FT    Data Analyst
# 291         291       2022               SE              FT    Data Analyst
# 292         292       2022               MI              FT  Data Scientist
# 293         293       2022               MI              FT  Data Scientist
# ..          ...        ...              ...             ...             ...
# 602         602       2022               SE              FT   Data Engineer
# 603         603       2022               SE              FT   Data Engineer
# 604         604       2022               SE              FT    Data Analyst
# 605         605       2022               SE              FT    Data Analyst
# 606         606       2022               MI              FT    AI Scientist
#
# ...

# %%
before_2021 = salaries.query("work_year < 2021 and job_title == 'Data Scientist' and employment_type == 'FT' and company_location == 'US'")
before_2021
# Out:
#     Unnamed: 0  work_year experience_level employment_type       job_title  \
# 32          32       2020               SE              FT  Data Scientist
# 40          40       2020               MI              FT  Data Scientist
# 48          48       2020               MI              FT  Data Scientist
# 57          57       2020               MI              FT  Data Scientist
# 58          58       2020               SE              FT  Data Scientist
# 59          59       2020               MI              FT  Data Scientist
# 63          63       2020               SE              FT  Data Scientist
# 68          68       2020               EN              FT  Data Scientist
#
#     salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 32   60000             EUR          68428                 GR           100
# 40   45760             USD          45760                 PH           100
# ...

# %%
### Basic groupby function with mean
salaries[["job_title", "salary"]].groupby("job_title").mean()
# Out:
#                                                 salary
# job_title
# 3D Computer Vision Researcher             4.000000e+05
# AI Scientist                              2.905714e+05
# Analytics Engineer                        1.750000e+05
# Applied Data Scientist                    1.724000e+05
# Applied Machine Learning Scientist        1.413500e+05
# BI Data Analyst                           1.902045e+06
# Big Data Architect                        1.250000e+05
# Big Data Engineer                         4.550000e+05
# Business Data Analyst                     3.550000e+05
# Cloud Data Engineer                       1.400000e+05
# Computer Vision Engineer                  8.350000e+04
# Computer Vision Software Engineer         1.003333e+05
# Data Analyst                              9.660496e+04
# Data Analytics Engineer                   6.175000e+04
# Data Analytics Lead                       4.050000e+05
# Data Analytics Manager                    1.271343e+05
# ...

# %%
### groupby function/method with aggregate columns

aggregated = salaries.groupby(
        ["experience_level", "employment_type"]
    ).agg(
        average_salary = ("salary", "mean"),
        total_salary = ("salary", "sum")
            )
aggregated
# Out:
#                                   average_salary  total_salary
# experience_level employment_type
# EN               CT                 64500.000000        129000
#                  FT                288759.696203      22812016
#                  PT                 49394.285714        345760
# EX               CT                416000.000000        416000
#                  FT                427515.000000      10687875
# MI               CT                270000.000000        270000
#                  FL                 44000.000000        132000
#                  FT                492527.029126     101460568
#                  PT                169666.666667        509000
# SE               CT                105000.000000        105000
#                  FL                 60000.000000         60000
#                  FT                214895.032374      59740819

# %%
sales = pd.read_csv("sales.csv")
sales
# Out:
#      product_code product_group  stock_qty    cost    price  last_week_sales  \
# 0            4187           PG2        498  420.76   569.91               13
# 1            4195           PG2        473  545.64   712.41               16
# 2            4204           PG2        968  640.42   854.91               22
# 3            4219           PG2        241  869.69  1034.55               14
# 4            4718           PG2       1401   12.54    26.59               50
# ..            ...           ...        ...     ...      ...              ...
# 995          8048           PG4        415   11.99    11.39               28
# 996          8050           PG4        -10    1.32     3.32               14
# 997           952           PG2       5388   37.71    61.74              331
# 998          1307           PG2      44996   31.44    42.74             1772
# 999          3018           PG5       1697    4.68    18.99               19
#
#      last_month_sales
# ...
